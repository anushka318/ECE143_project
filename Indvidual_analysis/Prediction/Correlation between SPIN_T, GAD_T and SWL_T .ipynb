# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
df_encoded = pd.read_csv("C:/Program Files/R Files/cleaned_data.csv")
df_encoded
# Out:
#        GAD1  GAD2  GAD3  GAD4  GAD5  GAD6  GAD7                  GADE  SWL1  \
# 0         0     0     0     0     1     0     0  Not difficult at all     3
# 1         1     2     2     2     0     1     0    Somewhat difficult     3
# 2         0     0     0     0     0     0     0  Not difficult at all     2
# 3         2     1     2     2     2     3     2        Very difficult     2
# 4         0     0     0     0     0     1     0  Not difficult at all     3
# ...     ...   ...   ...   ...   ...   ...   ...                   ...   ...
# 12076     1     0     0     1     0     1     1  Not difficult at all     6
# 12077     3     3     3     3     2     3     3   Extremely difficult     5
# 12078     0     0     0     0     0     0     0  Not difficult at all     6
# 12079     3     2     1     3     0     1     3    Somewhat difficult     2
# 12080     1     1     0     0     0     0     0    Somewhat difficult     5
#
#        SWL2  ...  Gender  Age                             Work  \
# 0         5  ...    Male   25        Unemployed / between jobs
# 1         5  ...    Male   41        Unemployed / between jobs
# 2         5  ...    Male   28                         Employed
# 3         2  ...    Male   19                         Employed
# 4         5  ...    Male   24                         Employed
# ...     ...  ...     ...  ...                              ...
# 12076     6  ...    Male   22  Student at college / university
# 12077     5  ...  Female   20  Student at college / university
# 12078     6  ...    Male   19  Student at college / university
# 12079     6  ...  Female   18                Student at school
# 12080     6  ...    Male   19  Student at college / university
#
#                                     Degree Reference  \
# 0                 Bachelor (or equivalent)    Reddit
# 1                 Bachelor (or equivalent)    Reddit
# 2                 Bachelor (or equivalent)    Reddit
# 3      High school diploma (or equivalent)    Reddit
# 4                 Bachelor (or equivalent)    Reddit
# ...                                    ...       ...
# 12076               Master (or equivalent)    Reddit
# 12077  High school diploma (or equivalent)    Reddit
# 12078  High school diploma (or equivalent)    Reddit
# 12079  High school diploma (or equivalent)    Reddit
# 12080  High school diploma (or equivalent)    Reddit
#
#                                                Playstyle GAD_T SWL_T SPIN_T  \
# 0                                           singleplayer     1    23    5.0
# 1                    multiplayer  online  with strangers     8    16   33.0
# 2      multiplayer  online  with online acquaintances...     0    17   11.0
# 3                    multiplayer  online  with strangers    14    14   13.0
# 4            multiplayer  online  with real life friends     1    17   13.0
# ...                                                  ...   ...   ...    ...
# 12076                multiplayer  online  with strangers     4    28    7.0
# 12077                multiplayer  online  with strangers    20    23   25.0
# 12078        multiplayer  online  with real life friends     0    32   10.0
# 12079                                       singleplayer    13    16   32.0
# 12080                multiplayer  online  with strangers     2    25   14.0
#
#        Residence_ISO3
# 0                 USA
# 1                 USA
# 2                 USA
# 3                 KOR
# 4                 USA
# ...               ...
# 12076             FRA
# 12077             USA
# 12078             NOR
# 12079             CAN
# 12080             CAN
#
# [12081 rows x 48 columns]

# %%
correlation_data = df_encoded[["SPIN_T", "GAD_T", "SWL_T"]]
correlation_data
# Out:
#        SPIN_T  GAD_T  SWL_T
# 0         5.0      1     23
# 1        33.0      8     16
# 2        11.0      0     17
# 3        13.0     14     14
# 4        13.0      1     17
# ...       ...    ...    ...
# 12076     7.0      4     28
# 12077    25.0     20     23
# 12078    10.0      0     32
# 12079    32.0     13     16
# 12080    14.0      2     25
#
# [12081 rows x 3 columns]

# %%
correlation_matrix = correlation_data.corr()
print("Correlation Matrix:")
print(correlation_matrix)
# Out:
# Correlation Matrix:
#           SPIN_T     GAD_T     SWL_T
# SPIN_T  1.000000  0.433217 -0.303185
# GAD_T   0.433217  1.000000 -0.392579
# SWL_T  -0.303185 -0.392579  1.000000

# %%
plt.figure(figsize=(6, 4))
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm", fmt=".2f", linewidths=0.5)
plt.title("Correlation Matrix: SPIN_T, GAD_T, SWL_T")
plt.show()

# %%
sns.pairplot(correlation_data)
plt.show()
